# %% [markdown]
# Create a notebook to create a dataframe and implement the following summary statistics functions:
# count
# describe
# min, max
# argmin, argmax
# idxmin, idxmax
# quantile
# sum
# mean
# median
# mad
# prod
# var
# std
# skew
# kurt
# cumsum
# cummin, cummax
# cumprod
# diff
# pct_change

# %%
import numpy as np
import pandas as pd
dta = {
    'name':['a','b','c','d','e','f'],
    'english':[45,56,78,56,54,98],
    'maths':[56,43,67,65,87,54],
    'science':[97,43,55,23,69,54]
}
df = pd.DataFrame(dta,index=[0,1,2,3,4,5])
df.index.name = 'Roll no.'
print(df)
print('Total number of non-NA rows in a dataframe\n', df.count())
print(df.describe())
print('min() returns the minimum value from each column\n',df.min())
print('max() returns the maximum value from each column\n',df.max())
arr1 = np.array(np.random.randint(10,100,size=15))
s1= pd.Series(arr1)
print(f'array: {arr1}\n series: {s1}\n')
print('argmin/argmax is an array function returns index of the minimum and maximum value in an array\n', arr1.argmin(), arr1.argmax())
print('idxmin() & idxmax() return the index label of minimum and maximum value in a series or dataframe\n',s1.idxmin(),s1.idxmax())
print(np.quantile(arr1,0.25))
print(np.quantile(arr1,0.50))
df = pd.DataFrame(s1)
print('mean : ',s1.mean(),'\nmedian : \n', s1.median(),'\nmode : \n',s1.mode(),'\n mad : \n', 'mad() is depreciated')
forprod = pd.Series([2,3,4,10,5])
print('below functions are applied on forprod series: ',forprod)
print('prod() returns the product of the function: ',forprod , forprod.prod())
print('var() returns the varaince of the dataset, i.e. how much a value vary from the mean.: ',forprod.var())
print('std() returns the standard deviation: ',forprod.std())
print('kurt(): (need to understand this)', df.kurt())
print('cumsum(): ',forprod.cumsum())
print('cummax(): ', forprod.cummax())
print('cummin(): ', forprod.cummin())
print('cumprod(): ', forprod.cumprod())
print('diff method returns an array with each element equal to the difference between that and previous element')
df = pd.DataFrame({"Date": pd.date_range("2024-03-01", "2024-03-07"),
                   "Price": [100, 105, 102, 108, 110, 112, 115]})
df['change']=df['Price'].diff()
print(df)
print(np.diff(arr1))
print('pct_change() basically means percentage change.',df['Price'].pct_change())
# Out:
#          name  english  maths  science
# Roll no.
# 0           a       45     56       97
# 1           b       56     43       43
# 2           c       78     67       55
# 3           d       56     65       23
# 4           e       54     87       69
# 5           f       98     54       54
# Total number of non-NA rows in a dataframe
#  name       6
# english    6
# maths      6
# science    6
# dtype: int64
#          english     maths    science
# count   6.000000   6.00000   6.000000
# mean   64.500000  62.00000  56.833333
# std    19.695177  14.96663  24.935249
# min    45.000000  43.00000  23.000000
# 25%    54.500000  54.50000  45.750000
# 50%    56.000000  60.50000  54.500000
# 75%    72.500000  66.50000  65.500000
# max    98.000000  87.00000  97.000000
# min() returns the minimum value from each column
#  name        a
# english    45
# maths      43
# science    23
# dtype: object
# max() returns the maximum value from each column
#  name        f
# english    98
# ...
